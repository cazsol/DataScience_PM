# %%
### HW2 - Data Science for product management
#Erik Bacilio
#November 4, 2017

# %%
import pandas as pd
from sklearn.cluster import KMeans
from IPython.display import display

# %%
# Loads data into data frame
bankData = pd.read_excel("Bank failure data.xlsx",sheetIndex=1)

# %%
print(bankData)
# Out:
#                               Bank Name Quarter  Tier One  Texas       Size  \
# 0                         Exchange Bank  2007Q4     14.90  19.36  32.852108
# 1                         Exchange Bank  2008Q1     14.30  20.86  33.542390
# 2                         Exchange Bank  2008Q2     14.15  20.89  34.140007
# 3                         Exchange Bank  2008Q3     14.13  18.74  34.038758
# 4                         Exchange Bank  2008Q4     14.21  21.82  34.059328
# 5                         Exchange Bank  2009Q1     14.35  21.72  33.945133
# 6                         Exchange Bank  2009Q2     13.95  32.14  33.369534
# 7                         Exchange Bank  2009Q3     13.73  27.52  33.531905
# 8                         Exchange Bank  2009Q4     13.08  49.37  34.072142
# 9                         Exchange Bank  2010Q1     13.25  54.35  34.285794
# 10    Peoples Bank, Biloxi, Mississippi  2007Q4     18.71   0.06  49.155081
# ...

# %%
bankData['Quarter']=bankData['Quarter'].replace({'2007Q4':2008,'2008Q1':2008.25,'2008Q2':2008.5,'2008Q3':2008.75,'2008Q4':2009,'2009Q1':2009.25,'2009Q2':2009.5,'2009Q3':2009.75,'2009Q4':2010,'2010Q1':2010.25})
set(bankData['Quarter'])

# %%
print(bankData)
# Out:
#                               Bank Name  Quarter  Tier One  Texas       Size  \
# 0                         Exchange Bank  2008.00     14.90  19.36  32.852108
# 1                         Exchange Bank  2008.25     14.30  20.86  33.542390
# 2                         Exchange Bank  2008.50     14.15  20.89  34.140007
# 3                         Exchange Bank  2008.75     14.13  18.74  34.038758
# 4                         Exchange Bank  2009.00     14.21  21.82  34.059328
# 5                         Exchange Bank  2009.25     14.35  21.72  33.945133
# 6                         Exchange Bank  2009.50     13.95  32.14  33.369534
# 7                         Exchange Bank  2009.75     13.73  27.52  33.531905
# 8                         Exchange Bank  2010.00     13.08  49.37  34.072142
# 9                         Exchange Bank  2010.25     13.25  54.35  34.285794
# 10    Peoples Bank, Biloxi, Mississippi  2008.00     18.71   0.06  49.155081
# ...

# %%
# create histogram

# %%
# delete rows with null values

# %%
# create heatmap

# %%
# create testing and training sets

# %%
# fit training sets

# %%
# predict bank failure for new data sample

# %%
#Get top 2 banks that are most likely to fail
